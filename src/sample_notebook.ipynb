# %% [markdown]
# # Default notebookThis default notebook is executed using a Lakeflow job as defined in resources/sample_job.job.yml.

# %%
# Set default catalog and schemacatalog = dbutils.widgets.get("catalog")schema = dbutils.widgets.get("schema")run_mode = dbutils.widgets.get("run_mode")spark.sql(f"USE CATALOG {catalog}")spark.sql(f"USE SCHEMA {schema}")

# %%
# Inspect taxi samples with a run-mode aware limitlimit = 10 if run_mode == "sample" else Nonedf = spark.read.table("samples.nyctaxi.trips")if limit:    df = df.limit(limit)df.select("pickup_datetime", "dropoff_datetime", "trip_distance").show(limit or 10)
